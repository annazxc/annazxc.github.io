# %% [markdown]
# <a href="https://colab.research.google.com/github/annazxc/updated-uni-projects/blob/main/lead_compensator_design.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![design_requirement.png](data:image/png;base64,...)

# %% [markdown]
# ![截圖 2025-03-14 晚上10.56.17.png](data:image/png;base64,...)

# %% [markdown]
# #Initial design

# %% [markdown]
# ![1.png](data:image/png;base64,...)![2.png](data:image/png;base64,...)

# %% [markdown]
# #Improved version

# %% [markdown]
# ##Firstly calculate the original condition of the system

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Uncompensated system phase margin: 28.0202 degrees.
# Uncompensated system gain crossover frequency: 46. 9782 rad/s.
# Uncompensated system steady-state error for ramp input: 1%
# Maximum phase lead with α = 0.4: 25.3769 degrees
# Time constant T: 0.087841 seconds.
# Gain K: 0.4
# Lead compensator transfer function:
#   tf with properties:
#
#        Numerator: {[0.0351 0.4000]}
#      Denominator: {[0.0351 1]}
#         Variable: 's'
#          IODelay: 0
#       InputDelay: 0
#      OutputDelay: 0
#        InputName: {''}
#        InputUnit: {''}
#       InputGroup: [1×1 struct]
#       OutputName: {''}
#       OutputUnit: {''}
#      OutputGroup: [1×1 struct]
#            Notes: [0×1 string]
#         UserData: []
#             Name: ''
#               Ts: 0
#         TimeUnit: 'seconds'
#     SamplingGrid: [1×1 struct]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Compensated system phase margin: 48.6422 degrees.
# Compensated system gain crossover frequency: 43.235 rad/s.
# Compensated system steady-state error for ramp input: 1%.
# Requirement verification:
# ✓ Phase margin > 45° requirement is met
# ✗ Steady-state error < 1% requirement is NOT met

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Alternative design:
# α = 0.3, T = 0.11411, K = 0.3
# Phase margin: 53.2118 degrees
# Steady-state error: 1%

# %% [markdown]
# ![image.png](data:image/png;base64,...)
